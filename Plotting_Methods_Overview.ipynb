# %%
from __future__ import print_function
import numpy as np
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt

# %%
np.random.seed(1)
x = np.arange(5)
y = np.random.randn(5)

fig, axes = plt.subplots(ncols=2, figsize=plt.figaspect(1./2))
vert_bars = axes[0].bar(x, y, color='lightblue', align='center')
hort_bars = axes[1].barh(x, y, color='lightblue', align='center')

axes[0].axhline(0, color='grey', linewidth=2)
axes[1].axvline(0, color='grey', linewidth=2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
fig, ax = plt.subplots()
vert_bars = ax.bar(x, y, color='lightblue', align='center')

for bar, height in zip(vert_bars, y):
    if height < 0:
        bar.set(edgecolor='darkred', color='salmon', linewidth=3)
        
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.linspace(0, 20 ,200)
y1 = 2 * x + 1
y2 = 3 * x + 1.2
y_mean = 0.5 * x * np.cos(2*x) + 2.5 * x +1.1

fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, color='yellow')
ax.plot(x, y_mean, color='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_obj = {'x':np.linspace(0, 10, 200),
           'y1':2 * x + 1,
           'y2':3 * x + 1.2,
           'mean':0.5 * x * np.cos(2*x) + 2.5 * x +1.1}

fig, ax = plt.subplots()

ax.fill_between(x, y1, y2, color='yellow')
ax.plot(x, y_mean, color='black')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.random.seed(1)

y_raw = np.random.randn(1000).cumsum() + 15
x_raw = np.linspace(0, 24, y_raw.size)

x_pos = x_raw.reshape(-1, 100).min(axis=1)
y_avg = y_raw.reshape(-1, 100).mean(axis=1)
y_err = y_raw.reshape(-1, 100).ptp(axis=1)

bar_width = x_pos[1] - x_pos[0]

x_pred = np.linspace(0, 30)
y_max_pred = y_avg[0] + y_err[0] + 2.3 * x_pred
y_min_pred = y_avg[0] - y_err[0] + 1.2 * x_pred

barcolor, linecolor, fillcolor = 'wheat', 'salmon', 'lightblue'
    
fig, ax = plt.subplots()
ax.fill_between(x_pos, y_avg, y_err, color=fillcolor)
ax.plot(x_pred, y_max_pred, color=linecolor)
ax.bar(x_pos, y_avg, color=barcolor, linewidth=3)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.cbook import get_sample_data
data = np.load('assets/bivariate_normal.npy')

fig, ax = plt.subplots()
im = ax.imshow(data)
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.load('assets/bivariate_normal.npy')
data.min()
# Out:
# -1.6939936746020778

# %%
fig, ax = plt.subplots()
cax = fig.add_axes([0.27, 0.8, 0.5, 0.06])

im = ax.imshow(data, cmap='gist_earth')
fig.colorbar(im, cax=cax, orientation='horizontal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.cbook import get_sample_data
data = np.load('assets/bivariate_normal.npy')

fig, ax = plt.subplots()
im = ax.imshow(data, cmap='seismic')
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
im = ax.imshow(data, 
               cmap='seismic',
               vmin=-2, vmax=2)
fig.colorbar(im)
plt.show()
# Out:
# /home/sameer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

plt.style.use('classic')

# Generate random data with different ranges...
data1 = np.random.random((10, 10))
data2 = 2 * np.random.random((10, 10))
data3 = 3 * np.random.random((10, 10))

# Set up our figure and axes...
fig, axes = plt.subplots(ncols=3, figsize=plt.figaspect(0.5))
fig.tight_layout() # Make the subplots fill up the figure a bit more...
cax = fig.add_axes([0.25, 0.1, 0.55, 0.03]) # Add an axes for the colorbar

# Now you're on your own!
im = axes[0].imshow(data1, interpolation='none', cmap='viridis', vmax=3, vmin=0)
im = axes[1].imshow(data2, interpolation='none', cmap='viridis', vmax=3, vmin=0)
im = axes[2].imshow(data3, interpolation='none', cmap='viridis', vmax=3, vmin=0)
fig.colorbar(im, cax=cax, orientation='horizontal')
plt.show()
# Out:
# /home/sameer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# <img src="data:image/png;base64,..." width="960">

# %%
np.random.seed(1)
data1 = np.random.random((10, 10))
data2 = 2 * np.random.random((10, 10))
data3 = 3 * np.random.random((10, 10))
data3.max()
# Out:
# 2.948451341191335
